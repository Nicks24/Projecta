# %% [markdown]
# # AIRLINE DATASET ANALYSIS WITH PYTHON

# %% [markdown]
# ## Required modules importing

# %% [markdown]
# 1. Importing numpy for mathematical operation on arrays and dataframe.
# 2. Importing pandas for reading data and data manipulation.
# 3. Importing matplotlib and seaborn to show the insights and visualization from the dataset.
# 4. Importing warnings for warning message that are typically issued in dataframe where it is useful to alert the user of
#    some condition in a program, where that condition(normally) doesn't warrent raising an exception and terminating the program.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set(style = 'darkgrid')

# %%
flight = pd.read_csv("C:/Users/Hp/OneDrive/Desktop/Airlines.csv")
flight
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR ? DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU ? IXR ? BBI ? BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
flight[flight['Route'].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR ? DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flight.shape
# Out:
# (10683, 11)

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
flight.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
flight.describe(include=object)
# Out:
#             Airline Date_of_Journey Source Destination            Route  \
# count         10683           10683  10683       10683            10682
# unique           12              44      5           6              128
# top     Jet Airways      18/05/2019  Delhi      Cochin  DEL ? BOM ? COK
# freq           3849             504   4537        4537             2376
#
#        Dep_Time Arrival_Time Duration Total_Stops Additional_Info
# count     10683        10683    10683       10682           10683
# unique      222         1343      368           5              10
# top       18:55        19:00   2h 50m      1 stop         No info
# freq        233          423      550        5625            8345

# %%
flight.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
flight["Route"].mode()
# Out:
# 0    DEL ? BOM ? COK
# Name: Route, dtype: object

# %%
flight['Route'] = flight['Route'].fillna(flight['Route'].mode()[0])

# %%
flight.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
flight['Total_Stops'].mode()
# Out:
# 0    1 stop
# Name: Total_Stops, dtype: object

# %%
flight['Total_Stops'].dtype
# Out:
# dtype('O')

# %%
flight['Total_Stops'] = flight['Total_Stops'].fillna(flight['Total_Stops'].mode()[0])

# %%
flight.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %% [markdown]
# ### From df.info() we can see that Date_Of_Journey is a object data type

# %% [markdown]
# 1. Therefore, we have to comvert this datatype into timestamp so that we can use that column properly to find the insights
# 2. For this we require pamdas to_datetime to convert object data type tp datetime dtype

# %%
flight['Date_of_Journey'] = pd.to_datetime(flight['Date_of_Journey'])

# %%
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR ? DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  datetime64[ns]
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10683 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10683 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 918.2+ KB

# %%
flight['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %% [markdown]
# ### Now we can see that Total_Stops is categorical column so we can replace that column data into catogeries

# %%
flight['Total_Stops'].replace({"non-stop": 0, "1 stop": 1, "2 stops": 2, "3 stops": 3, "4 stops": 4},inplace=True)

# %%
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR ? DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration  Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m            0         No info   3897
# 1    05:50         13:15   7h 25m            2         No info   7662
# 2    09:25  04:25 10 Jun      19h            2         No info  13882
# 3    18:05         23:30   5h 25m            1         No info   6218
# 4    16:50         21:35   4h 45m            1         No info  13302

# %% [markdown]
# ## VISUALIZATION OF DATASET

# %% [markdown]
# #### How many flights with respect to their stopages?

# %%
#From this Histogram we can see that no. of flights and their stopages
#In this data maximum flights have 1 sotpages
#And their are few flights which have 3 and 4 stopages

plt.title('Number of Flight Stopage')
plt.hist(flight['Total_Stops'],color='blue')
plt.xlabel('Stopages')
plt.ylabel('No. of flights')
plt.xticks(flight['Total_Stops'].unique())
plt.yticks(flight['Total_Stops'].value_counts())
plt.show()

# %%
flight['Total_Stops'].unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %%
flight['Total_Stops'].value_counts()
# Out:
# 1    5626
# 0    3491
# 2    1520
# 3      45
# 4       1
# Name: Total_Stops, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.bar(flight['Airline'],flight['Total_Stops'],color='red')
plt.xlabel('Airlines')
plt.ylabel('Total stopages')
plt.xticks(rotation=90)
plt.yticks(flight['Total_Stops'].unique())
plt.show()

# %%
flight['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
flight[flight['Total_Stops']==4]
# Out:
#         Airline Date_of_Journey    Source Destination  \
# 9182  Air India      2019-01-03  Banglore   New Delhi
#
#                                   Route Dep_Time  Arrival_Time Duration  \
# 9182  BLR ? CCU ? BBI ? HYD ? VGA ? DEL    05:50  11:20 02 Mar  29h 30m
#
#       Total_Stops  Additional_Info  Price
# 9182            4  Change airports  17686

# %%
flight[flight['Airline']=='Vistara Premium economy']
# Out:
#                       Airline Date_of_Journey    Source Destination  \
# 426   Vistara Premium economy      2019-03-03  Banglore   New Delhi
# 7657  Vistara Premium economy      2019-01-03   Chennai     Kolkata
# 8615  Vistara Premium economy      2019-06-04  Banglore       Delhi
#
#           Route Dep_Time Arrival_Time Duration  Total_Stops Additional_Info  \
# 426   BLR ? DEL    16:00        18:35   2h 35m            0         No info
# 7657  MAA ? CCU    07:05        09:20   2h 15m            0         No info
# 8615  BLR ? DEL    11:30        14:20   2h 50m            0         No info
#
#       Price
# 426   11793
# 7657   9125
# 8615   5969

# %% [markdown]
# #### List the flights which have 3 stopages

# %%
flight.loc[flight['Total_Stops']==3].count()
# Out:
# Airline            45
# Date_of_Journey    45
# Source             45
# Destination        45
# Route              45
# Dep_Time           45
# Arrival_Time       45
# Duration           45
# Total_Stops        45
# Additional_Info    45
# Price              45
# dtype: int64

# %% [markdown]
# ##### Flights which have 4 stopages

# %%
flight.loc[flight['Total_Stops']==4].count()
# Out:
# Airline            1
# Date_of_Journey    1
# Source             1
# Destination        1
# Route              1
# Dep_Time           1
# Arrival_Time       1
# Duration           1
# Total_Stops        1
# Additional_Info    1
# Price              1
# dtype: int64

# %% [markdown]
# #### Which flight is expensive and cheapest ?

# %%
#This boxplot show the outliers in the flight prices
#Only Vistara Premium Economy and Trujet has no outliers
plt.boxplot(flight['Price'])
plt.xticks(rotation=90,size=11)
plt.title("Check outliers")
plt.show()

# %%
flight['Price'].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
q3 = flight['Price'].quantile(0.75)
q1 = flight['Price'].quantile(0.25)

# %%
IQR = q3-q1
IQR
# Out:
# 7096.0

# %%
upp_li = q3+1.5*(IQR)
upp_li
# Out:
# 23017.0

# %%
low_li = q1-1.5*(IQR)
low_li
# Out:
# -5367.0

# %% [markdown]
# ### Variations of Flight Price from sources

# %%
#From this boxplot we can see the maximum outliers are in Banglore and minimum in Kolkata
plt.figure(figsize=(10,6))
sns.boxplot(flight['Source'],flight['Price'],data=flight)
plt.xticks(rotation=90,size=15)
plt.title("Variations of Prices from Source")
plt.show()

# %%
type(flight)
# Out:
# pandas.core.frame.DataFrame

# %%
flight.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR ? DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL ? LKO ? BOM ? COK
#
#   Dep_Time  Arrival_Time Duration  Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m            0         No info   3897
# 1    05:50         13:15   7h 25m            2         No info   7662
# 2    09:25  04:25 10 Jun      19h            2         No info  13882

# %%
flight[flight['Total_Stops']==4]
# Out:
#         Airline Date_of_Journey    Source Destination  \
# 9182  Air India      2019-01-03  Banglore   New Delhi
#
#                                   Route Dep_Time  Arrival_Time Duration  \
# 9182  BLR ? CCU ? BBI ? HYD ? VGA ? DEL    05:50  11:20 02 Mar  29h 30m
#
#       Total_Stops  Additional_Info  Price
# 9182            4  Change airports  17686

# %%
flight.loc[flight["Total_Stops"]==3]
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 402            Air India      2019-06-15     Delhi      Cochin
# 919            Air India      2019-12-05   Kolkata    Banglore
# 1218           Air India      2019-06-27     Delhi      Cochin
# 1665           Air India      2019-01-03  Banglore   New Delhi
# 2172           Air India      2019-05-18     Delhi      Cochin
# 2623           Air India      2019-12-03    Mumbai   Hyderabad
# 2633   Multiple carriers      2019-06-03     Delhi      Cochin
# 2718           Air India      2019-09-03     Delhi      Cochin
# 2814           Air India      2019-12-03  Banglore   New Delhi
# 2822           Air India      2019-05-24   Kolkata    Banglore
# 3157   Multiple carriers      2019-05-15     Delhi      Cochin
# 3220           Air India      2019-06-05   Kolkata    Banglore
# 3317   Multiple carriers      2019-03-03     Delhi      Cochin
# 3496           Air India      2019-12-03  Banglore   New Delhi
# ...

# %%
flight.loc[flight['Total_Stops']==2]
# Out:
#            Airline Date_of_Journey   Source Destination  \
# 1        Air India      2019-01-05  Kolkata    Banglore
# 2      Jet Airways      2019-09-06    Delhi      Cochin
# 15       Air India      2019-03-03    Delhi      Cochin
# 18       Air India      2019-12-06    Delhi      Cochin
# 25     Jet Airways      2019-09-06    Delhi      Cochin
# ...            ...             ...      ...         ...
# 10668  Jet Airways      2019-09-05    Delhi      Cochin
# 10670    Air India      2019-12-05  Kolkata    Banglore
# 10672  Jet Airways      2019-06-27    Delhi      Cochin
# 10673  Jet Airways      2019-05-27    Delhi      Cochin
# 10682    Air India      2019-09-05    Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration  Total_Stops  \
# 1      CCU ? IXR ? BBI ? BLR    05:50         13:15   7h 25m            2
# 2      DEL ? LKO ? BOM ? COK    09:25  04:25 10 Jun      19h            2
# ...

# %%
flight.loc[flight['Total_Stops']==1]
# Out:
#                  Airline Date_of_Journey    Source Destination  \
# 3                 IndiGo      2019-12-05   Kolkata    Banglore
# 4                 IndiGo      2019-01-03  Banglore   New Delhi
# 6            Jet Airways      2019-12-03  Banglore   New Delhi
# 7            Jet Airways      2019-01-03  Banglore   New Delhi
# 8            Jet Airways      2019-12-03  Banglore   New Delhi
# ...                  ...             ...       ...         ...
# 10666        Jet Airways      2019-12-06     Delhi      Cochin
# 10667        Jet Airways      2019-12-03  Banglore   New Delhi
# 10669          Air India      2019-06-15     Delhi      Cochin
# 10674        Jet Airways      2019-12-03  Banglore   New Delhi
# 10676  Multiple carriers      2019-01-05     Delhi      Cochin
#
#                  Route Dep_Time  Arrival_Time Duration  Total_Stops  \
# 3      CCU ? NAG ? BLR    18:05         23:30   5h 25m            1
# 4      BLR ? NAG ? DEL    16:50         21:35   4h 45m            1
# ...

# %%
flight.loc[flight['Total_Stops']==0]
# Out:
#            Airline Date_of_Journey    Source Destination      Route Dep_Time  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi  BLR ? DEL    22:20
# 5         SpiceJet      2019-06-24   Kolkata    Banglore  CCU ? BLR    09:00
# 11          IndiGo      2019-04-18   Kolkata    Banglore  CCU ? BLR    20:20
# 12       Air India      2019-06-24   Chennai     Kolkata  MAA ? CCU    11:40
# 14          IndiGo      2019-04-24   Kolkata    Banglore  CCU ? BLR    17:15
# ...            ...             ...       ...         ...        ...      ...
# 10677     SpiceJet      2019-05-21  Banglore       Delhi  BLR ? DEL    05:55
# 10678     Air Asia      2019-09-04   Kolkata    Banglore  CCU ? BLR    19:55
# 10679    Air India      2019-04-27   Kolkata    Banglore  CCU ? BLR    20:45
# 10680  Jet Airways      2019-04-27  Banglore       Delhi  BLR ? DEL    08:20
# 10681      Vistara      2019-01-03  Banglore   New Delhi  BLR ? DEL    11:30
#
# ...

# %%
flight['Date_of_Journey'].mode()
# Out:
# 0   2019-05-18
# Name: Date_of_Journey, dtype: datetime64[ns]

# %%
flight['Date_of_Journey'].unique()
# Out:
# array(['2019-03-24T00:00:00.000000000', '2019-01-05T00:00:00.000000000',
#        '2019-09-06T00:00:00.000000000', '2019-12-05T00:00:00.000000000',
#        '2019-01-03T00:00:00.000000000', '2019-06-24T00:00:00.000000000',
#        '2019-12-03T00:00:00.000000000', '2019-05-27T00:00:00.000000000',
#        '2019-01-06T00:00:00.000000000', '2019-04-18T00:00:00.000000000',
#        '2019-09-05T00:00:00.000000000', '2019-04-24T00:00:00.000000000',
#        '2019-03-03T00:00:00.000000000', '2019-04-15T00:00:00.000000000',
#        '2019-12-06T00:00:00.000000000', '2019-06-03T00:00:00.000000000',
#        '2019-03-21T00:00:00.000000000', '2019-03-04T00:00:00.000000000',
#        '2019-06-05T00:00:00.000000000', '2019-05-15T00:00:00.000000000',
#        '2019-06-18T00:00:00.000000000', '2019-06-15T00:00:00.000000000',
#        '2019-06-04T00:00:00.000000000', '2019-05-18T00:00:00.000000000',
#        '2019-06-27T00:00:00.000000000', '2019-05-21T00:00:00.000000000',
# ...

# %% [markdown]
# ### Extracting Day and Month from the Journey

# %% [markdown]
# For this we require pandas to_datetime to convert object data type to datetime dtype
# .dt.day method will extract only day of that date
# .dt.month method will extract only month of that date

# %%
flight['Day_of_Journey'] = flight['Date_of_Journey'].dt.day
flight['Month_of_Journey'] = flight['Date_of_Journey'].dt.month

# %%
flight.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR ? DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU ? IXR ? BBI ? BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL ? LKO ? BOM ? COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU ? NAG ? BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR ? NAG ? DEL
#
#   Dep_Time  Arrival_Time Duration  Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m            0         No info   3897
# 1    05:50         13:15   7h 25m            2         No info   7662
# 2    09:25  04:25 10 Jun      19h            2         No info  13882
# 3    18:05         23:30   5h 25m            1         No info   6218
# 4    16:50         21:35   4h 45m            1         No info  13302
#
#    Day_of_Journey  Month_of_Journey
# 0              24                 3
# ...

# %%
#Since, we have converted Date_od_Journey columns into integers, Now we can drop as it is of no use
flight.drop(columns=['Date_of_Journey'],inplace=True)

# %%
flight['Day_of_Journey'].unique()
# Out:
# array([24,  5,  6,  3, 27, 18, 15, 21,  4], dtype=int64)

# %%
a = list(flight['Month_of_Journey'].unique())
a
# Out:
# [3, 1, 9, 12, 6, 5, 4]

# %% [markdown]
# ## Now check on what month have maximum flights take off

# %%
plt.figure(figsize=(8,8))
month=list(flight['Month_of_Journey'])
airline=list(flight['Airline'])
plt.scatter(airline,month)
plt.xticks(rotation=90)
plt.yticks(flight['Month_of_Journey'].unique())
plt.title('Month Have Maximum Flights Take off')
plt.xlabel('Airlines')
plt.ylabel('Month')
plt.show()

# %%
flight[flight['Month_of_Journey']==10]
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Route, Dep_Time, Arrival_Time, Duration, Total_Stops, Additional_Info, Price, Day_of_Journey, Month_of_Journey]
# Index: []

# %% [markdown]
# ## On which month the maximum earnings?

# %%
#Aggregating the month with respect to price
flight.groupby(['Month_of_Journey'])['Price'].sum()
# Out:
# Month_of_Journey
# 1     11279591
# 3     18647220
# 4      2217885
# 5     19414875
# 6     23369151
# 9     13429373
# 12     8719011
# Name: Price, dtype: int64

# %%
pr=flight.groupby(['Month_of_Journey'])['Price'].agg(['sum']).reset_index()
list(pr.iloc[:,1])
# Out:
# [11279591, 18647220, 2217885, 19414875, 23369151, 13429373, 8719011]

# %%
b = flight.groupby(['Month_of_Journey'])['Price'].agg(['sum']).iloc[:,0]
b = list(b)
b
# Out:
# [11279591, 18647220, 2217885, 19414875, 23369151, 13429373, 8719011]

# %%
c = list(flight['Month_of_Journey'].unique())
c
# Out:
# [3, 1, 9, 12, 6, 5, 4]

# %%
plt.bar(c,b)
plt.title('Prices')
plt.show()

# %%
flight['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
flight['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
flight.replace({'New Delhi' : 'Delhi'},inplace=True)

# %%
flight["Source"].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
flight['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
flight['Destination'].unique()
# Out:
# array(['Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Hyderabad'],
#       dtype=object)

# %% [markdown]
# ## Remove 'New' in 'New Delhi' from destination column

# %%
destination=[]
for i in flight['Destination'] :
    if i=='New Delhi' :
        destiantion.append(i.replace('New Delhi','Delhi'))
    else :
        destination.append(i)

# %%
flight['Destination'].unique()
# Out:
# array(['Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Hyderabad'],
#       dtype=object)

# %%
#Drop the destination column to add the new column
flight.drop(columns=['Destination'],inplace=True)

# %%
flight.head()
# Out:
#        Airline    Source                  Route Dep_Time  Arrival_Time  \
# 0       IndiGo  Banglore              BLR ? DEL    22:20  01:10 22 Mar
# 1    Air India   Kolkata  CCU ? IXR ? BBI ? BLR    05:50         13:15
# 2  Jet Airways     Delhi  DEL ? LKO ? BOM ? COK    09:25  04:25 10 Jun
# 3       IndiGo   Kolkata        CCU ? NAG ? BLR    18:05         23:30
# 4       IndiGo  Banglore        BLR ? NAG ? DEL    16:50         21:35
#
#   Duration  Total_Stops Additional_Info  Price  Day_of_Journey  \
# 0   2h 50m            0         No info   3897              24
# 1   7h 25m            2         No info   7662               5
# 2      19h            2         No info  13882               6
# 3   5h 25m            1         No info   6218               5
# 4   4h 45m            1         No info  13302               3
#
#    Month_of_Journey
# 0                 3
# 1                 1
# 2                 9
# 3                12
# 4                 1

# %%
#Adding the new column destination which have filtered by city names
flight['Destination'] = pd.Series(destination)

# %%
flight.head()
# Out:
#        Airline    Source                  Route Dep_Time  Arrival_Time  \
# 0       IndiGo  Banglore              BLR ? DEL    22:20  01:10 22 Mar
# 1    Air India   Kolkata  CCU ? IXR ? BBI ? BLR    05:50         13:15
# 2  Jet Airways     Delhi  DEL ? LKO ? BOM ? COK    09:25  04:25 10 Jun
# 3       IndiGo   Kolkata        CCU ? NAG ? BLR    18:05         23:30
# 4       IndiGo  Banglore        BLR ? NAG ? DEL    16:50         21:35
#
#   Duration  Total_Stops Additional_Info  Price  Day_of_Journey  \
# 0   2h 50m            0         No info   3897              24
# 1   7h 25m            2         No info   7662               5
# 2      19h            2         No info  13882               6
# 3   5h 25m            1         No info   6218               5
# 4   4h 45m            1         No info  13302               3
#
#    Month_of_Journey Destination
# 0                 3       Delhi
# 1                 1    Banglore
# 2                 9      Cochin
# ...

# %%
#Making list of all the columns 
cols = flight.columns.tolist()
cols
# Out:
# ['Airline',
#  'Source',
#  'Route',
#  'Dep_Time',
#  'Arrival_Time',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info',
#  'Price',
#  'Day_of_Journey',
#  'Month_of_Journey',
#  'Destination']

# %%
#Slicing to arrange the position of Destination column
cols = cols[0:3]+cols[-1:]+cols[3:11]
cols
# Out:
# ['Airline',
#  'Source',
#  'Route',
#  'Destination',
#  'Dep_Time',
#  'Arrival_Time',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info',
#  'Price',
#  'Day_of_Journey',
#  'Month_of_Journey']

# %%
# Assigning all the columns in the dataframe
flight = flight[cols]

# %%
flight.head()
# Out:
#        Airline    Source                  Route Destination Dep_Time  \
# 0       IndiGo  Banglore              BLR ? DEL       Delhi    22:20
# 1    Air India   Kolkata  CCU ? IXR ? BBI ? BLR    Banglore    05:50
# 2  Jet Airways     Delhi  DEL ? LKO ? BOM ? COK      Cochin    09:25
# 3       IndiGo   Kolkata        CCU ? NAG ? BLR    Banglore    18:05
# 4       IndiGo  Banglore        BLR ? NAG ? DEL       Delhi    16:50
#
#    Arrival_Time Duration  Total_Stops Additional_Info  Price  Day_of_Journey  \
# 0  01:10 22 Mar   2h 50m            0         No info   3897              24
# 1         13:15   7h 25m            2         No info   7662               5
# 2  04:25 10 Jun      19h            2         No info  13882               6
# 3         23:30   5h 25m            1         No info   6218               5
# 4         21:35   4h 45m            1         No info  13302               3
#
#    Month_of_Journey
# 0                 3
# 1                 1
# 2                 9
# ...

# %%
flight['Airline'].unique()
# Out:
# array(['IndiGo', 'Air India', 'Jet Airways', 'SpiceJet',
#        'Multiple carriers', 'GoAir', 'Vistara', 'Air Asia',
#        'Vistara Premium economy', 'Jet Airways Business',
#        'Multiple carriers Premium economy', 'Trujet'], dtype=object)

# %%
flight['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
flight['Destination'].unique()
# Out:
# array(['Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Hyderabad'],
#       dtype=object)

# %% [markdown]
# ## Checking the availability of flight with respect to Source and Destination

# %%
destin = flight.groupby(['Source','Destination'])['Airline'].value_counts()
destin
# Out:
# Source    Destination  Airline
# Banglore  Delhi        Jet Airways                           788
#                        IndiGo                                523
#                        Air India                             332
#                        Vistara                               185
#                        SpiceJet                              181
#                        GoAir                                  93
#                        Air Asia                               89
#                        Jet Airways Business                    4
#                        Vistara Premium economy                 2
# Chennai   Kolkata      IndiGo                                184
#                        SpiceJet                              128
#                        Vistara                                43
#                        Air India                              25
#                        Vistara Premium economy                 1
# ...

# %%
# See the longest and the shortest route with duration by time taken
dest = flight.groupby(['Route','Duration'])['Airline'].value_counts()
dest
# Out:
# Route            Duration  Airline
# BLR ? AMD ? DEL  15h 15m   Vistara       3
#                  20h       Air India     1
#                  23h 25m   Air India     2
#                  27h 45m   Vistara       4
#                  5h        IndiGo        3
#                                         ..
# MAA ? CCU        2h 20m    Vistara      18
#                  2h 25m    IndiGo       49
#                  2h 35m    SpiceJet     13
#                            IndiGo        1
#                  2h 45m    IndiGo        3
# Name: Airline, Length: 1211, dtype: int64
